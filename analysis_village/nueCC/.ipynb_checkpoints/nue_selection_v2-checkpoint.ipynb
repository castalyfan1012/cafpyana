# %% [markdown]
# # $\nu_e$ CC Inclusive Selection

# %%
# %matplotlib inline
 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
import sys, os
 
# ── paths ──
CAFPYANA_WD = "/home/castalyf/cafpyana"
ANALYSIS_DIR = "."         
PLOT_DIR     = "./nuecc_plots"
MC_FILE      = "/exp/sbnd/data/users/castalyf/nue_sel/production_files/gen1/mc1e20_1_skimmed.df"
SKIM_FILE    = 
TARGET_POT   = 6.6e20
TITLE        = "SBND $\\nu_e$ CC Inclusive"
 
os.makedirs(PLOT_DIR, exist_ok=True)
 
for p in [CAFPYANA_WD, CAFPYANA_WD + "/pyanalib", ANALYSIS_DIR]:
    if p not in sys.path:
        sys.path.insert(0, p)
 
import pyanalib.split_df_helpers as splh
import nue_helpers   as nh
import nue_selection as ns
 
# %load_ext autoreload
# %autoreload 2
 
print("matplotlib backend:", plt.get_backend())
print("All imports OK ✓")
# Out:
# matplotlib backend: inline
# All imports OK ✓

# %% [markdown]
# ## 1. Check the keys in the sample

# %%
# import os
# import pandas as pd

# print("=== MC_FILE diagnostics ===")
# print(f"MC_FILE = {MC_FILE!r}")
# print(f"File exists?          {os.path.exists(MC_FILE)}")
# print(f"File size (bytes)     {os.path.getsize(MC_FILE) if os.path.exists(MC_FILE) else 'N/A'}")
# print(f"Is file?              {os.path.isfile(MC_FILE)}")

# try:
#     with pd.HDFStore(MC_FILE, mode='r') as store:
#         print(f"Available keys:       {store.keys()}")
#         print(f"Number of keys:       {len(store.keys())}")
# except Exception as e:
#     print(f"Error opening HDFStore: {e}")

# %% [markdown]
# ## 2. Load the data frame

# %%
#  print("Loading evt table …")
# evtdf = splh.load_dfs(MC_FILE, ["evt"])["evt"]
# print(f"  shape       : {evtdf.shape}")
# print(f"  index names : {evtdf.index.names}")
# print(f"  top columns : {evtdf.columns.get_level_values(0).unique().tolist()}")
 
# print("\nLoading mcnu table …")
# mcnudf = splh.load_dfs(MC_FILE, ["mcnu"])["mcnu"]
# print(f"  shape       : {mcnudf.shape}")
 
# print("\nLoading POT …")
# histpotdf = splh.load_dfs(MC_FILE, ["histpotdf"], n_max_concat=5)["histpotdf"]
# total_pot, pot_scale = nh.compute_pot_scale(histpotdf, TARGET_POT)
# print(f"  Total POT    : {total_pot:.3e}")
# print(f"  Target POT   : {TARGET_POT:.3e}")
# print(f"  Scale factor : {pot_scale:.3f}")
 
# # ── Convenience wrappers (created once, reused everywhere) ──
# rp = nh.reco_particles(evtdf)     # particle -> rec -> dlp -> particles
# tp = nh.true_particles(evtdf)     # particle -> rec -> dlp_true -> particles
# ri = nh.reco_interactions(evtdf)  # rec -> dlp
# ti = nh.true_interactions(evtdf)  # rec -> dlp_true
 
# print("\nExample access:")
# print("  rp.pid.value_counts():\n", rp.pid.value_counts().head())
# print("  rp[0].ke:\n", rp[0].ke.values[:5], "…")
# print("  ri.vertex.x.head():\n", ri.vertex.x.head())

# %%
# ── Load all skimmed files at once ──────────────────────────────────────────
skimmed_files = sorted(glob.glob(os.path.join(SKIM_DIR, "*_20*_skimmed.df")))
print(f"Found {len(skimmed_files)} skimmed files")

print("Loading evt tables …")
dfs = []
for i, f in enumerate(tqdm(skimmed_files, desc="Loading")):
    df = pd.read_hdf(f, key="evt_0")
    # Remap __ntuple to be globally unique across files
    df.index = df.index.set_levels(
        df.index.levels[0] + i * 1000,  # offset __ntuple per file
        level=0
    )
    dfs.append(df)
evtdf = pd.concat(dfs, axis=0)
print(f"  shape       : {evtdf.shape}")
print(f"  index names : {evtdf.index.names}")

# ── POT + scale from the JSON sidecar (no mcnu needed) ──────────────────────
with open(os.path.join(SKIM_DIR, "efficiency_denominators.json")) as f:
    _denom = json.load(f)

total_pot = _denom["total_pot"]
pot_scale = TARGET_POT / total_pot
print(f"\n  Total POT    : {total_pot:.3e}")
print(f"  Target POT   : {TARGET_POT:.3e}")
print(f"  Scale factor : {pot_scale:.3f}")

# ── Convenience wrappers (unchanged) ────────────────────────────────────────
rp = nh.reco_particles(evtdf)
tp = nh.true_particles(evtdf)
ri = nh.reco_interactions(evtdf)
ti = nh.true_interactions(evtdf)

print("\nExample access:")
print("  rp.pid.value_counts():\n", rp.pid.value_counts().head())
print("  ri.vertex.x.head():\n", ri.vertex.x.head())
# Out:
# Found 3 skimmed files
# Loading evt tables …
# Loading:   0%|          | 0/3 [00:00<?, ?it/s]
#   shape       : (930045, 288)
#   index names : ['__ntuple', 'entry', 'rec.dlp..index', 'rec.dlp.particles..index']
#
#   Total POT    : 4.529e+20
#   Target POT   : 6.600e+20
#   Scale factor : 1.457
#
# Example access:
#   rp.pid.value_counts():
#  pid
# 1    579791
# 2    232604
# 0     56168
# 4     48059
# 3     13423
# Name: count, dtype: int64
#   ri.vertex.x.head():
#  __ntuple  entry  rec.dlp..index  rec.dlp.particles..index
# 0         0      0               0                          -178.650009
#                                  1                          -178.650009
#                                  2                          -178.650009
#                                  3                          -178.650009
#                                  4                          -178.650009
# Name: x, dtype: float32

# %%
# visualize the structure

cols = [" -> ".join([str(c) for c in col if c != ""]) for col in evtdf.columns]

# Determine the midpoint
mid = (len(cols) + 1) // 2
left = cols[:mid]
right = cols[mid:]

# Set a fixed width for alignment
width = max(len(c) for c in left) + 4

for l, r in zip(left, right + [""] * (len(left) - len(right))):
    print(f"{l:<{width}}{r}")

###############
# # save a few events into csv 

# subset = evtdf.reset_index().head(100)
# subset.to_csv("evtdf_preview.csv", index=False)
# print("Saved: evtdf_preview.csv")

# interaction_subset = (
#     evtdf
#     .xs((1, 0, 0), level=['__ntuple', 'entry', 'rec.dlp..index'])
#     .reset_index()
# )
# interaction_subset.to_csv("interaction01_preview.csv", index=False)
# print("Saved: interaction01_preview.csv")


# export_df = pd.concat([
#     evtdf["rec"]["dlp_true"]["particles"],
#     evtdf["rec"]["dlp"]["particles"]
# ], axis=1).reset_index()

# export_df.head(1000).to_csv("particle_preview.csv", index=False)
# print("Saved: particle_preview.csv")
# Out:
# rec -> dlp -> match_ids                             rec -> dlp -> particles -> mcs_ke_per_pid -> I3
# rec -> dlp -> match_overlaps                        rec -> dlp -> particles -> mcs_ke_per_pid -> I4
# rec -> dlp -> cathode_offset                        rec -> dlp -> particles -> mcs_ke_per_pid -> I5
# rec -> dlp -> depositions_sum                       rec -> dlp -> particles -> momentum -> x
# rec -> dlp -> flash_hypo_pe                         rec -> dlp -> particles -> momentum -> y
# rec -> dlp -> flash_total_pe                        rec -> dlp -> particles -> momentum -> z
# rec -> dlp -> id                                    rec -> dlp -> particles -> num_fragments
# rec -> dlp -> is_cathode_crosser                    rec -> dlp -> particles -> p
# rec -> dlp -> is_contained                          rec -> dlp -> particles -> pdg_code
# rec -> dlp -> is_fiducial                           rec -> dlp -> particles -> pid
# rec -> dlp -> is_flash_matched                      rec -> dlp -> particles -> pid_scores -> I0
# rec -> dlp -> is_matched                            rec -> dlp -> particles -> pid_scores -> I1
# rec -> dlp -> is_time_contained                     rec -> dlp -> particles -> pid_scores -> I2
# rec -> dlp -> is_truth                              rec -> dlp -> particles -> pid_scores -> I3
# rec -> dlp -> num_particles                         rec -> dlp -> particles -> pid_scores -> I4
# rec -> dlp -> num_primary_particles                 rec -> dlp -> particles -> pid_scores -> I5
# rec -> dlp -> particle_counts -> I0                 rec -> dlp -> particles -> primary_scores -> I0
# rec -> dlp -> particle_counts -> I1                 rec -> dlp -> particles -> primary_scores -> I1
# rec -> dlp -> particle_counts -> I2                 rec -> dlp -> particles -> shape
# rec -> dlp -> particle_counts -> I3                 rec -> dlp -> particles -> size
# rec -> dlp -> particle_counts -> I4                 rec -> dlp -> particles -> start_dedx
# rec -> dlp -> particle_counts -> I5                 rec -> dlp -> particles -> start_dir -> x
# rec -> dlp -> primary_particle_counts -> I0         rec -> dlp -> particles -> start_dir -> y
# rec -> dlp -> primary_particle_counts -> I1         rec -> dlp -> particles -> start_dir -> z
# rec -> dlp -> primary_particle_counts -> I2         rec -> dlp -> particles -> start_point -> x
# rec -> dlp -> primary_particle_counts -> I3         rec -> dlp -> particles -> start_point -> y
# rec -> dlp -> primary_particle_counts -> I4         rec -> dlp -> particles -> start_point -> z
# rec -> dlp -> primary_particle_counts -> I5         rec -> dlp -> particles -> start_straightness
# rec -> dlp -> size                                  rec -> dlp -> particles -> vertex_distance
# rec -> dlp -> vertex -> x                           rec.dlp_true..index_y
# rec -> dlp -> vertex -> y                           rec.dlp_true.particles..index
# rec -> dlp -> vertex -> z                           rec -> dlp_true -> particles -> ancestor_pdg_code
# rec.dlp_true..index_x                               rec -> dlp_true -> particles -> ancestor_position -> I0
# rec -> dlp_true -> bjorken_x                        rec -> dlp_true -> particles -> ancestor_position -> I1
# rec -> dlp_true -> cathode_offset                   rec -> dlp_true -> particles -> ancestor_position -> I2
# rec -> dlp_true -> current_type                     rec -> dlp_true -> particles -> ancestor_t
# rec -> dlp_true -> depositions_adapt_q_sum          rec -> dlp_true -> particles -> ancestor_track_id
# rec -> dlp_true -> depositions_adapt_sum            rec -> dlp_true -> particles -> calo_ke
# rec -> dlp_true -> depositions_g4_sum               rec -> dlp_true -> particles -> cathode_offset
# rec -> dlp_true -> depositions_q_sum                rec -> dlp_true -> particles -> csda_ke
# rec -> dlp_true -> depositions_sum                  rec -> dlp_true -> particles -> csda_ke_per_pid -> I0
# rec -> dlp_true -> distance_travel                  rec -> dlp_true -> particles -> csda_ke_per_pid -> I1
# rec -> dlp_true -> energy_init                      rec -> dlp_true -> particles -> csda_ke_per_pid -> I2
# rec -> dlp_true -> energy_transfer                  rec -> dlp_true -> particles -> csda_ke_per_pid -> I3
# rec -> dlp_true -> flash_hypo_pe                    rec -> dlp_true -> particles -> csda_ke_per_pid -> I4
# rec -> dlp_true -> flash_total_pe                   rec -> dlp_true -> particles -> csda_ke_per_pid -> I5
# rec -> dlp_true -> hadronic_invariant_mass          rec -> dlp_true -> particles -> depositions_adapt_q_sum
# rec -> dlp_true -> id                               rec -> dlp_true -> particles -> depositions_adapt_sum
# rec -> dlp_true -> inelasticity                     rec -> dlp_true -> particles -> depositions_g4_sum
# rec -> dlp_true -> interaction_mode                 rec -> dlp_true -> particles -> depositions_q_sum
# rec -> dlp_true -> interaction_type                 rec -> dlp_true -> particles -> depositions_sum
# rec -> dlp_true -> is_cathode_crosser               rec -> dlp_true -> particles -> distance_travel
# rec -> dlp_true -> is_contained                     rec -> dlp_true -> particles -> end_dir -> x
# rec -> dlp_true -> is_fiducial                      rec -> dlp_true -> particles -> end_dir -> y
# rec -> dlp_true -> is_flash_matched                 rec -> dlp_true -> particles -> end_dir -> z
# rec -> dlp_true -> is_matched                       rec -> dlp_true -> particles -> end_momentum -> I0
# rec -> dlp_true -> is_time_contained                rec -> dlp_true -> particles -> end_momentum -> I1
# rec -> dlp_true -> is_truth                         rec -> dlp_true -> particles -> end_momentum -> I2
# rec -> dlp_true -> lepton_p                         rec -> dlp_true -> particles -> end_p
# rec -> dlp_true -> lepton_pdg_code                  rec -> dlp_true -> particles -> end_point -> x
# rec -> dlp_true -> lepton_track_id                  rec -> dlp_true -> particles -> end_point -> y
# rec -> dlp_true -> mct_index                        rec -> dlp_true -> particles -> end_point -> z
# rec -> dlp_true -> momentum -> x                    rec -> dlp_true -> particles -> end_position -> I0
# rec -> dlp_true -> momentum -> y                    rec -> dlp_true -> particles -> end_position -> I1
# rec -> dlp_true -> momentum -> z                    rec -> dlp_true -> particles -> end_position -> I2
# rec -> dlp_true -> momentum_transfer                rec -> dlp_true -> particles -> end_t
# rec -> dlp_true -> momentum_transfer_mag            rec -> dlp_true -> particles -> energy_deposit
# rec -> dlp_true -> nu_id                            rec -> dlp_true -> particles -> energy_init
# rec -> dlp_true -> nucleon                          rec -> dlp_true -> particles -> first_step -> I0
# rec -> dlp_true -> num_particles                    rec -> dlp_true -> particles -> first_step -> I1
# rec -> dlp_true -> num_primary_particles            rec -> dlp_true -> particles -> first_step -> I2
# rec -> dlp_true -> orig_id                          rec -> dlp_true -> particles -> group_id
# rec -> dlp_true -> particle_counts -> I0            rec -> dlp_true -> particles -> group_primary
# rec -> dlp_true -> particle_counts -> I1            rec -> dlp_true -> particles -> id
# rec -> dlp_true -> particle_counts -> I2            rec -> dlp_true -> particles -> interaction_id
# rec -> dlp_true -> particle_counts -> I3            rec -> dlp_true -> particles -> interaction_primary
# rec -> dlp_true -> particle_counts -> I4            rec -> dlp_true -> particles -> is_cathode_crosser
# rec -> dlp_true -> particle_counts -> I5            rec -> dlp_true -> particles -> is_contained
# rec -> dlp_true -> pdg_code                         rec -> dlp_true -> particles -> is_matched
# rec -> dlp_true -> position -> I0                   rec -> dlp_true -> particles -> is_primary
# rec -> dlp_true -> position -> I1                   rec -> dlp_true -> particles -> is_time_contained
# rec -> dlp_true -> position -> I2                   rec -> dlp_true -> particles -> is_truth
# rec -> dlp_true -> primary_particle_counts -> I0    rec -> dlp_true -> particles -> is_valid
# rec -> dlp_true -> primary_particle_counts -> I1    rec -> dlp_true -> particles -> ke
# rec -> dlp_true -> primary_particle_counts -> I2    rec -> dlp_true -> particles -> last_step -> I0
# rec -> dlp_true -> primary_particle_counts -> I3    rec -> dlp_true -> particles -> last_step -> I1
# rec -> dlp_true -> primary_particle_counts -> I4    rec -> dlp_true -> particles -> last_step -> I2
# rec -> dlp_true -> primary_particle_counts -> I5    rec -> dlp_true -> particles -> length
# rec -> dlp_true -> quark                            rec -> dlp_true -> particles -> mass
# rec -> dlp_true -> reco_vertex -> x                 rec -> dlp_true -> particles -> mcs_ke
# rec -> dlp_true -> reco_vertex -> y                 rec -> dlp_true -> particles -> mcs_ke_per_pid -> I0
# rec -> dlp_true -> reco_vertex -> z                 rec -> dlp_true -> particles -> mcs_ke_per_pid -> I1
# rec -> dlp_true -> size                             rec -> dlp_true -> particles -> mcs_ke_per_pid -> I2
# rec -> dlp_true -> size_adapt                       rec -> dlp_true -> particles -> mcs_ke_per_pid -> I3
# rec -> dlp_true -> size_g4                          rec -> dlp_true -> particles -> mcs_ke_per_pid -> I4
# rec -> dlp_true -> target                           rec -> dlp_true -> particles -> mcs_ke_per_pid -> I5
# rec -> dlp_true -> theta                            rec -> dlp_true -> particles -> mcst_index
# rec -> dlp_true -> track_id                         rec -> dlp_true -> particles -> mct_index
# rec -> dlp_true -> vertex -> x                      rec -> dlp_true -> particles -> momentum -> x
# rec -> dlp_true -> vertex -> y                      rec -> dlp_true -> particles -> momentum -> y
# rec -> dlp_true -> vertex -> z                      rec -> dlp_true -> particles -> momentum -> z
# rec -> dlp -> particles -> match_ids                rec -> dlp_true -> particles -> nu_id
# rec -> dlp -> particles -> match_overlaps           rec -> dlp_true -> particles -> num_fragments
# rec -> dlp -> particles -> axial_spread             rec -> dlp_true -> particles -> num_voxels
# rec -> dlp -> particles -> calo_ke                  rec -> dlp_true -> particles -> orig_group_id
# rec -> dlp -> particles -> cathode_offset           rec -> dlp_true -> particles -> orig_id
# rec -> dlp -> particles -> chi2_per_pid -> I0       rec -> dlp_true -> particles -> orig_interaction_id
# rec -> dlp -> particles -> chi2_per_pid -> I1       rec -> dlp_true -> particles -> orig_parent_id
# rec -> dlp -> particles -> chi2_per_pid -> I2       rec -> dlp_true -> particles -> p
# rec -> dlp -> particles -> chi2_per_pid -> I3       rec -> dlp_true -> particles -> parent_id
# rec -> dlp -> particles -> chi2_per_pid -> I4       rec -> dlp_true -> particles -> parent_pdg_code
# rec -> dlp -> particles -> chi2_per_pid -> I5       rec -> dlp_true -> particles -> parent_position -> I0
# rec -> dlp -> particles -> chi2_pid                 rec -> dlp_true -> particles -> parent_position -> I1
# rec -> dlp -> particles -> csda_ke                  rec -> dlp_true -> particles -> parent_position -> I2
# rec -> dlp -> particles -> csda_ke_per_pid -> I0    rec -> dlp_true -> particles -> parent_t
# rec -> dlp -> particles -> csda_ke_per_pid -> I1    rec -> dlp_true -> particles -> parent_track_id
# rec -> dlp -> particles -> csda_ke_per_pid -> I2    rec -> dlp_true -> particles -> pdg_code
# rec -> dlp -> particles -> csda_ke_per_pid -> I3    rec -> dlp_true -> particles -> pid
# rec -> dlp -> particles -> csda_ke_per_pid -> I4    rec -> dlp_true -> particles -> position -> I0
# rec -> dlp -> particles -> csda_ke_per_pid -> I5    rec -> dlp_true -> particles -> position -> I1
# rec -> dlp -> particles -> depositions_sum          rec -> dlp_true -> particles -> position -> I2
# rec -> dlp -> particles -> directional_spread       rec -> dlp_true -> particles -> reco_end_dir -> I0
# rec -> dlp -> particles -> end_dir -> x             rec -> dlp_true -> particles -> reco_end_dir -> I1
# rec -> dlp -> particles -> end_dir -> y             rec -> dlp_true -> particles -> reco_end_dir -> I2
# rec -> dlp -> particles -> end_dir -> z             rec -> dlp_true -> particles -> reco_ke
# rec -> dlp -> particles -> end_point -> x           rec -> dlp_true -> particles -> reco_length
# rec -> dlp -> particles -> end_point -> y           rec -> dlp_true -> particles -> reco_momentum -> I0
# rec -> dlp -> particles -> end_point -> z           rec -> dlp_true -> particles -> reco_momentum -> I1
# rec -> dlp -> particles -> id                       rec -> dlp_true -> particles -> reco_momentum -> I2
# rec -> dlp -> particles -> interaction_id           rec -> dlp_true -> particles -> reco_start_dir -> I0
# rec -> dlp -> particles -> is_cathode_crosser       rec -> dlp_true -> particles -> reco_start_dir -> I1
# rec -> dlp -> particles -> is_contained             rec -> dlp_true -> particles -> reco_start_dir -> I2
# rec -> dlp -> particles -> is_matched               rec -> dlp_true -> particles -> shape
# rec -> dlp -> particles -> is_primary               rec -> dlp_true -> particles -> size
# rec -> dlp -> particles -> is_time_contained        rec -> dlp_true -> particles -> size_adapt
# rec -> dlp -> particles -> is_truth                 rec -> dlp_true -> particles -> size_g4
# rec -> dlp -> particles -> is_valid                 rec -> dlp_true -> particles -> start_dir -> x
# rec -> dlp -> particles -> ke                       rec -> dlp_true -> particles -> start_dir -> y
# rec -> dlp -> particles -> length                   rec -> dlp_true -> particles -> start_dir -> z
# rec -> dlp -> particles -> mass                     rec -> dlp_true -> particles -> start_point -> x
# rec -> dlp -> particles -> mcs_ke                   rec -> dlp_true -> particles -> start_point -> y
# rec -> dlp -> particles -> mcs_ke_per_pid -> I0     rec -> dlp_true -> particles -> start_point -> z
# rec -> dlp -> particles -> mcs_ke_per_pid -> I1     rec -> dlp_true -> particles -> t
# rec -> dlp -> particles -> mcs_ke_per_pid -> I2     rec -> dlp_true -> particles -> track_id

# %% [markdown]
# ## 3. True signal definition

# %%
# #  Truth classification ──────────────────────────────────────────
 
# truth_cat = ns.classify_truth(evtdf, verbose=True)
# # truth_cat : pd.Series indexed by interaction MultiIndex, values 0-6 (or -1)
 
# # True-signal interaction index (used for efficiency denominator)
# sig_inter_idx = ns.true_signal_index(evtdf)
# print(f"\nTrue nueCC-in-FV signal interactions: {len(sig_inter_idx):,}")

# %%
# ── Truth classification (runs on skimmed df — same code, fewer rows) ───────
truth_cat = ns.classify_truth(evtdf, verbose=True)

# ── Signal denominator: use the pre-counted JSON value ──────────────────────
# Do NOT recount from evtdf — skimmed df dropped some pre-FM/FV events,
# so true_signal_index(evtdf) would undercount signal that didn't pass FM/FV
# but IS part of the true denominator.
n_true_signal_total = _denom["n_true_signal"]   # counted before any cut
print(f"\nTrue nueCC-in-FV signal (all files, pre-cut): {n_true_signal_total:,}")

# sig_inter_idx is still useful for purity/efficiency alignment within
# the skimmed df (events that survived FM+FV and are signal):
sig_inter_idx = ns.true_signal_index(evtdf)
print(f"True signal visible in skimmed df          : {len(sig_inter_idx):,}")
# Out:
# classify_truth: reading true-interaction flags …
#   is_nu        :   32,121
#   is_cc        :   25,408
#   is_fv (true) :   17,019
#   true_elec    :    1,501
#   true_muon    :  232,980
#   has_pi0      :    4,191
#
# === Truth category summary ===
#   cat  0  nueCC FV (signal)     :       65
#   cat  1  nueCC out FV          :       36
#   cat  2  numuCC + π⁰           :    1,510
#   cat  3  NC π⁰                 :    1,242
#   cat  4  other numuCC          :   17,454
#   cat  5  other NC              :    5,471
#   cat  6  cosmic                :  251,995
#   cat  7  other neutrino        :    6,343
#   total                     :  284,116
#
# True nueCC-in-FV signal (all files, pre-cut): 22,724
# True signal visible in skimmed df          : 109

# %% [markdown]
# ## 4. Selection

# %%
# # Cut flow + purity / efficiency ─────────────────────────────────
 
# cut_flow = ns.build_cut_flow(evtdf)
# # cut_flow["single_electron"]["inter_index"]  → final selection
# # cut_flow["single_electron"]["particle_mask"] → particle-level mask
 
# # ── Align truth categories with interaction-level cut-flow indices ──
# il = nh.inter_levels(evtdf)
 
# def _inter_sel_mask(inter_idx):
#     """Bool array (interaction level) matching truth_cat index."""
#     return truth_cat.index.isin(inter_idx)
 
# def _sig_mask():
#     return truth_cat.index.isin(sig_inter_idx)
 
# # Build parallel lists for pur/eff calculation
# cut_masks  = [_inter_sel_mask(cut_flow[c]["inter_index"]) for c in ns.CUT_NAMES]
# sig_mask   = _sig_mask()
 
# # Purity / efficiency (excluding precut from purity since all events selected)
# purs, effs = nh.pur_eff_cut_flow(cut_masks, sig_mask)
 
# # ── Summary table ──
# print(f"\n{'Cut':<26} {'N inter':>9}  {'Purity':>8}  {'Efficiency':>10}")
# print("─" * 60)
# for name, label, mask, pur, eff in zip(ns.CUT_NAMES, ns.CUT_LABELS,
#                                         cut_masks, purs, effs):
#     n = cut_flow[name]["inter_index"].shape[0]
#     p = f"{pur*100:.1f}%" if not np.isnan(pur) else "—"
#     e = f"{eff*100:.1f}%" if not np.isnan(eff) else "—"
#     print(f"  {label:<24} {n:>9,}  {p:>8}  {e:>10}")

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CELL 1: Cut-flow table — all cuts in notebook, all counts exact
# ══════════════════════════════════════════════════════════════════════════════

# ── Cut flow ─────────────────────────────────────────────
cut_flow      = ns.build_cut_flow(evtdf)
truth_cat     = ns.classify_truth(evtdf, verbose=False)

# ── EVERYTHING now defined in skimmed space ─────────────
sig_inter_idx = ns.true_signal_index(evtdf)

common_idx = truth_cat.index
sig_mask   = common_idx.isin(sig_inter_idx)

# ── NEW denominator (skimmed-space baseline) ────────────
n_sig_precut   = len(sig_inter_idx)
n_inter_precut = len(common_idx)

# ── Per-stage counts ────────────────────────────────────
def _stage_counts(cut_name):
    idx = cut_flow[cut_name]["inter_index"]

    n_i = len(idx)

    # signal inside skimmed space
    n_s = int(sig_mask[common_idx.isin(idx)].sum())

    pur = n_s / n_i if n_i > 0 else 0.0
    return n_i, n_s, pur


n_inter_fm, n_sig_fm, pur_fm = _stage_counts("valid_flashmatch")
n_inter_fv, n_sig_fv, pur_fv = _stage_counts("fiducial")
n_inter_se, n_sig_se, pur_se = _stage_counts("single_electron")

# ── table ───────────────────────────────────────────────
print(f"\n{'Cut':<26} {'N inter':>9}  {'Purity':>8}  {'Efficiency':>12}")
print("─" * 62)

print(f"  {'No cut':<24} {n_inter_precut:>9,}  {'—':>8}  {'100.0%':>12}")
print(f"  {'Flash match':<24} {n_inter_fm:>9,}  {pur_fm*100:>7.1f}%  {n_sig_fm/n_sig_precut*100:>11.1f}%")
print(f"  {'In FV':<24} {n_inter_fv:>9,}  {pur_fv*100:>7.1f}%  {n_sig_fv/n_sig_precut*100:>11.1f}%")
print(f"  {'Final state topology':<24} {n_inter_se:>9,}  {pur_se*100:>7.1f}%  {n_sig_se/n_sig_precut*100:>11.1f}%")
# Out:
# Building cut flow:   0%|          | 0/4 [00:00<?, ?it/s]
# Cut                          N inter    Purity    Efficiency
# ──────────────────────────────────────────────────────────────
#   No cut                     284,116         —        100.0%
#   Flash match                 25,432      0.4%         91.7%
#   In FV                       14,640      0.7%         89.0%
#   Final state topology           677     10.2%         63.3%

# %% [markdown]
# ### 4-1. Efficiency/purity stats

# %%
# # %% ── CELL 6: Cut-flow table + purity/efficiency summary plot ────────────────

# # ── Purity / efficiency line plot ──
# fig, ax_pe = plt.subplots(figsize=(9, 5))          # slightly wider for more labels

# # Use the SAME label list that was used to compute purs/effs
# # (this automatically works for both the old 4-cut version and the new 10-cut version)
# labels_to_plot = ns.CUT_LABELS

# ax_pe.plot(labels_to_plot, [p * 100 for p in purs], "o-", color="orange", label="Purity [%]")
# ax_pe.plot(labels_to_plot, [e * 100 for e in effs], "s--", color="steelblue", label="Efficiency [%]")

# ax_pe.set_ylim(0, 105)
# ax_pe.set_xlabel("Cut")
# ax_pe.set_ylabel("Percentage [%]")
# ax_pe.legend(loc="lower right")
# ax_pe.grid(True, alpha=0.3)

# # Rotate x-labels if there are many cuts (looks much better)
# plt.xticks(rotation=45, ha="right")

# # ── Optional: add the table below the plot (same figure) ──
# # If you also want the table on the same figure, uncomment the next lines:
# ax_table = fig.add_axes([0.1, -0.65, 0.8, 0.55])   # adjust y-position as needed
# nh.create_purity_efficiency_table(purs, effs, labels_to_plot, ax_table)

# plt.tight_layout()
# plt.show()

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CELL 2: Binned efficiency/purity + efficiency matrix (KE and cos θ)
# All counts are now exact — no back-estimation needed because the pre-cut
# df is fully available (no skim-time cuts were applied).
# ══════════════════════════════════════════════════════════════════════════════

true_ke_all       = ns.true_leading_electron_ke(evtdf)
true_costheta_all = ns.true_leading_electron_costheta(evtdf)

true_ke_aligned = true_ke_all.reindex(common_idx)
true_ct_aligned = true_costheta_all.reindex(common_idx)

# sig_true_vals: bool array aligned to common_idx
sig_true_vals = sig_mask   # already defined in Cell 1 as common_idx.isin(sig_inter_idx)

# Per-cut selection masks aligned to common_idx
sel_fm = common_idx.isin(cut_flow["valid_flashmatch"]["inter_index"])
sel_fv = common_idx.isin(cut_flow["fiducial"]["inter_index"])
sel_se = common_idx.isin(cut_flow["single_electron"]["inter_index"])

# ── Binned efficiency & purity: single_electron cut ───────────────────────
ke_vals    = true_ke_aligned.fillna(-999).values
xbin_range = (0, 2000)
xbin_count = 30
ke_bins_t  = np.linspace(xbin_range[0], xbin_range[1], xbin_count + 1)

centers, purs_b, effs_b, counts_b = nh.pur_eff_binned(
    values   = ke_vals,
    bins     = ke_bins_t,
    sel_mask = sel_se,
    sig_mask = sig_true_vals,
)
fig_bin, ax_bin = plt.subplots(figsize=(8, 6))
ax2 = ax_bin.twinx()
nh.plot_eff_pur_vs_bin(
    bin_centers  = centers,
    purs         = purs_b,
    effs         = effs_b,
    counts_true  = counts_b,
    xlabel       = "True leading electron KE [MeV]",
    title        = fr"{TITLE} efficiency & purity vs true electron KE",
    ax           = ax_bin,
    ax2          = ax2,
)
plt.show()
nh.save_plot("binned_eff_pur_ke", fig=fig_bin, folder_name=PLOT_DIR)

# %%
ke_bins_c     = np.array([0, 200, 400, 600, 800, 1000, 1500, 2000, np.inf])
ke_bin_labels = ["0–200","200–400","400–600","600–800","800–1k","1k–1.5k","1.5k–2k",">2k"]
n_bins        = len(ke_bins_c) - 1

ALL_CUT_NAMES  = ["precut", "valid_flashmatch", "fiducial", "single_electron"]
ALL_CUT_LABELS = ["No cut", "Flash match", "In FV", "Final state topology"]

# truth_cat.index is a pandas MultiIndex — .isin() on a MultiIndex returns a
# plain numpy bool array directly (no .values needed)
_idx = truth_cat.index

sel_fm_arr   = _idx.isin(cut_flow["valid_flashmatch"]["inter_index"])
sel_fv_arr   = _idx.isin(cut_flow["fiducial"]["inter_index"])
sel_se_arr   = _idx.isin(cut_flow["single_electron"]["inter_index"])
sig_true_arr = _idx.isin(sig_inter_idx)

sel_by_cut = {
    "precut"           : np.ones(len(_idx), dtype=bool),
    "valid_flashmatch" : sel_fm_arr,
    "fiducial"         : sel_fv_arr,
    "single_electron"  : sel_se_arr,
}

ke_vals = true_ke_aligned.fillna(-999).values

eff_matrix_ke   = np.zeros((n_bins, len(ALL_CUT_NAMES)))
count_matrix_ke = np.zeros((n_bins, len(ALL_CUT_NAMES)))

for i, (lo, hi) in enumerate(zip(ke_bins_c[:-1], ke_bins_c[1:])):
    in_bin       = (ke_vals >= lo) & (ke_vals < hi)
    n_precut_bin = int((in_bin & sig_true_arr).sum())

    for ci, cut_name in enumerate(ALL_CUT_NAMES):
        n_sig_bin              = int((in_bin & sig_true_arr & sel_by_cut[cut_name]).sum())
        count_matrix_ke[i, ci] = n_sig_bin
        eff_matrix_ke[i, ci]   = n_sig_bin / n_precut_bin if n_precut_bin > 0 else 0.0

fig, ax = nh.plot_matrix_binned(
    eff_matrix_ke, count_matrix_ke,
    bin_values=np.arange(n_bins), bin_labels=ke_bin_labels,
    cut_labels=ALL_CUT_LABELS, remove_dummy_col=False,
    xlabel="True leading electron KE [MeV]", title="Efficiency",
    cmap="Blues", vmin=0, vmax=1,
)
fig.tight_layout()
nh.save_plot("eff_matrix_true_ke", fig=fig, folder_name=PLOT_DIR)

# ── cos θ matrix ──────────────────────────────────────────────────────────
ct_vals       = true_ct_aligned.fillna(-2).values
ct_bins_c     = np.array([-1.0, -0.5, 0.0, 0.5, 0.8, 0.9, 1.0])
ct_bin_labels = ["-1–-0.5","-0.5–0","0–0.5","0.5–0.8","0.8–0.9","0.9–1.0"]
n_bins_ct     = len(ct_bins_c) - 1

eff_matrix_ct   = np.zeros((n_bins_ct, len(ALL_CUT_NAMES)))
count_matrix_ct = np.zeros((n_bins_ct, len(ALL_CUT_NAMES)))

for i, (lo, hi) in enumerate(zip(ct_bins_c[:-1], ct_bins_c[1:])):
    in_bin       = (ct_vals >= lo) & (ct_vals < hi)
    n_precut_bin = int((in_bin & sig_true_arr).sum())

    for ci, cut_name in enumerate(ALL_CUT_NAMES):
        n_sig_bin               = int((in_bin & sig_true_arr & sel_by_cut[cut_name]).sum())
        count_matrix_ct[i, ci]  = n_sig_bin
        eff_matrix_ct[i, ci]    = n_sig_bin / n_precut_bin if n_precut_bin > 0 else 0.0

fig, ax = nh.plot_matrix_binned(
    eff_matrix_ct, count_matrix_ct,
    bin_values=np.arange(n_bins_ct), bin_labels=ct_bin_labels,
    cut_labels=ALL_CUT_LABELS, remove_dummy_col=False,
    xlabel=r"True leading electron $\cos\theta$", title="Efficiency",
    cmap="Blues", vmin=0, vmax=1,
)
fig.tight_layout()
nh.save_plot("eff_matrix_true_cos", fig=fig, folder_name=PLOT_DIR)

# %%
# # ── Efficiency matrix (cos θ bins × cut stages) ──────────────────────────────
# true_costheta_all     = ns.true_leading_electron_costheta(evtdf)
# true_costheta_aligned = true_costheta_all.reindex(common_idx)
# ct_bins_c     = np.array([-1.0, -0.5, 0.0, 0.5, 0.8, 0.9, 1.0])
# ct_bin_labels = ["-1–-0.5","-0.5–0","0–0.5","0.5–0.8","0.8–0.9","0.9–1.0"]
# n_bins_ct = len(ct_bins_c) - 1

# ct_vals = true_costheta_aligned.fillna(-2).values

# eff_matrix_ct   = np.zeros((n_bins_ct, len(ALL_CUT_NAMES)))
# count_matrix_ct = np.zeros((n_bins_ct, len(ALL_CUT_NAMES)))

# for i, (lo, hi) in enumerate(zip(ct_bins_c[:-1], ct_bins_c[1:])):
#     in_bin    = (ct_vals >= lo) & (ct_vals < hi)
#     sig_total = int((in_bin & sig_true_vals).sum())
#     if sig_total == 0:
#         continue

#     sig_precut_est = round(sig_total / eff_fv_agg) if eff_fv_agg > 0 else sig_total

#     for ci, cut_name in enumerate(ALL_CUT_NAMES):
#         if cut_name == "precut":
#             eff_matrix_ct[i, ci]   = 1.0
#             count_matrix_ct[i, ci] = sig_precut_est

#         elif cut_name == "valid_flashmatch":
#             eff_matrix_ct[i, ci]   = eff_fm_agg
#             count_matrix_ct[i, ci] = round(sig_precut_est * eff_fm_agg)

#         elif cut_name == "fiducial":
#             eff_matrix_ct[i, ci]   = eff_fv_agg
#             count_matrix_ct[i, ci] = sig_total

#         else:
#             cut_idx      = cut_flow[cut_name]["inter_index"]
#             reco_sel     = common_idx.isin(cut_idx)
#             sig_selected = int((in_bin & sig_true_vals & reco_sel).sum())
#             eff_matrix_ct[i, ci]   = sig_selected / sig_precut_est if sig_precut_est > 0 else 0
#             count_matrix_ct[i, ci] = sig_selected

# fig, ax = nh.plot_matrix_binned(
#     eff_matrix_ct, count_matrix_ct,
#     bin_values=np.arange(n_bins_ct), bin_labels=ct_bin_labels,
#     cut_labels=ALL_CUT_LABELS, remove_dummy_col=False,
#     xlabel=r"True leading electron $\cos\theta$", title="Efficiency",
#     cmap="Blues", vmin=0, vmax=1,
# )
# fig.tight_layout()
# nh.save_plot("eff_matrix_true_cos", fig=fig, folder_name=PLOT_DIR)

# %% [markdown]
# ### 4-2. Histograms

# %%
# ══════════════════════════════════════════════════════════════════════════════
# CELL 3: Stacked reco histograms (KE and cos θ) — unchanged logic, uses
#          variables already defined in Cell 1/2 above
# ══════════════════════════════════════════════════════════════════════════════

reco_ke_all  = ns.leading_electron_ke(evtdf)
reco_cos_all = ns.leading_electron_costheta(evtdf)

sel_idx  = cut_flow["single_electron"]["inter_index"]
all_cats = sorted([c for c in nh.CAT_COLORS if c >= 0])

def _cat_ke_values(cat_code, sel_inter_idx):
    cat_inter = truth_cat[truth_cat == cat_code].index
    return reco_ke_all.reindex(sel_inter_idx.intersection(cat_inter)).dropna().values

def _cat_cos_values(cat_code, sel_inter_idx):
    cat_inter = truth_cat[truth_cat == cat_code].index
    return reco_cos_all.reindex(sel_inter_idx.intersection(cat_inter)).dropna().values

ke_bins  = np.linspace(0, 2000, 41)
cos_bins = np.linspace(-1, 1, 41)

fig_ke, ax_ke = plt.subplots(figsize=(8, 6))
nh.plot_stacked_hist(
    series_list = [_cat_ke_values(c, sel_idx) for c in all_cats],
    labels      = [nh.CAT_LABELS[c] for c in all_cats],
    colors      = [nh.CAT_COLORS[c] for c in all_cats],
    bins        = ke_bins,
    xlabel      = "Reco leading electron KE [MeV]",
    title       = fr"{TITLE}",
    pot_label   = f"MC {TARGET_POT:.1e} POT",
    ax          = ax_ke,
)
plt.show()
nh.save_plot("reco_electron_ke", fig=fig_ke, folder_name=PLOT_DIR)

fig_cos, ax_cos = plt.subplots(figsize=(8, 6))
nh.plot_stacked_hist(
    series_list = [_cat_cos_values(c, sel_idx) for c in all_cats],
    labels      = [nh.CAT_LABELS[c] for c in all_cats],
    colors      = [nh.CAT_COLORS[c] for c in all_cats],
    bins        = cos_bins,
    xlabel      = r"Reco leading electron $\cos\theta$",
    title       = fr"{TITLE}",
    pot_label   = f"MC {TARGET_POT:.1e} POT",
    ax          = ax_cos,
)
plt.show()
nh.save_plot("reco_electron_costheta", fig=fig_cos, folder_name=PLOT_DIR)

# %% [markdown]
# ## 5. Shower quality cuts

# %%
import nue_helpers as nh
import nue_selection as ns

# ── Only run the basic cut flow (precut → single_electron) ───────────────
# shower_qual_cuts() is NOT called here — thresholds are not yet defined.
cut_flow_base = ns.build_cut_flow(evtdf)
truth_cats    = ns.classify_truth(evtdf, verbose=False)

# %%
import nue_helpers as nh

shower_cuts = [
    ("pid_scores",         [0.5, 1.0], "Electron PID Softmax Score",        [0.5, 1.0,  0.005], '>',  'left',  "f1_thrsh_electron_pid_score"),
    ("primary_scores",     [0.5, 1.0], "Electron Primary Softmax Score",     [0.5, 1.0,  0.005], '>',  'left',  "f1_thrsh_electron_primary_score"),
    ("start_dedx",         [0.0, 8.0], "Start dE/dx [MeV/cm]",              [0.0, 8.0,  0.05],  '<',  'right', "f1_thrsh_start_dedx"),
    ("vertex_distance",    [0.0, 10.], "Conversion Distance [cm]",           [0.0, 10.0, 0.05],  '<',  'right', "f1_thrsh_vertex_distance"),
    ("directional_spread", [0.0, 0.2], "Leading Shower Directional Spread",  [0.0, 0.2,  0.001], '<',  'right', "f1_thrsh_directional_spread"),
    ("axial_spread",       [0.0, 1.0], "Leading Shower Axial Spread",        [0.0, 1.0,  0.005], '>',  'left',  "f1_thrsh_axial_spread"),
]

opt_thresholds = {}
for col, bounds, xlabel, trange, cdir, lloc, sname in shower_cuts:
    opt_t, opt_f1 = nh.threshold_plots(
        evtdf            = evtdf,
        cut_flow_result  = cut_flow_base,
        cut_stage        = "single_electron",
        metric_col       = col,
        bounds           = bounds,
        xaxis_name       = xlabel,
        plot_title       = f"{xlabel} — threshold scan",
        threshold_range  = trange,
        cut_dir          = cdir,
        legend_loc       = lloc,
        truth_categories = truth_cats,
        save_name        = sname,
        plot_folder      = PLOT_DIR,
    )
    opt_thresholds[col] = opt_t

print("\nOptimal thresholds summary:")
for k, v in opt_thresholds.items():
    print(f"  {k:<30s}: {v:.4f}")

# ── THEN, once thresholds are reviewed, run shower_qual_cuts in a separate cell ──
# cut_flow_full = ns.shower_qual_cuts(evtdf)

# %%
# %% ── Shower quality cuts
cut_flow = ns.shower_qual_cuts(evtdf)   # now much faster, no duplication

# ── Align truth categories with interaction-level cut-flow indices ──
il = nh.inter_levels(evtdf)

def _inter_sel_mask(inter_idx):
    """Bool array (interaction level) matching truth_cat index."""
    return truth_cat.index.isin(inter_idx)

def _sig_mask():
    return truth_cat.index.isin(sig_inter_idx)

# Build parallel lists for pur/eff calculation
cut_masks = [_inter_sel_mask(cut_flow[c]["inter_index"]) for c in ns.CUT_NAMES_MORE]
sig_mask = _sig_mask()

# Purity / efficiency (excluding precut from purity since all events selected)
purs, effs = nh.pur_eff_cut_flow(cut_masks, sig_mask)

# ── Summary table ──
print(f"\n{'Cut':<26} {'N inter':>9} {'Purity':>8} {'Efficiency':>10}")
print("─" * 60)
for name, label, mask, pur, eff in zip(ns.CUT_NAMES_MORE, ns.CUT_LABELS_MORE,
                                        cut_masks, purs, effs):
    n = cut_flow[name]["inter_index"].shape[0]
    p = f"{pur*100:.1f}%" if not np.isnan(pur) else "—"
    e = f"{eff*100:.1f}%" if not np.isnan(eff) else "—"
    print(f" {label:<24} {n:>9,} {p:>8} {e:>10}")

# %% [markdown]
# ### 5-1. Efficiency/purity stats

# %%
# %% ── CELL 6: Cut-flow table + purity/efficiency summary plot ────────────────

# ── Purity / efficiency line plot ──
fig, ax_pe = plt.subplots(figsize=(7, 4))
ax_pe.plot(ns.CUT_LABELS_MORE, [p * 100 for p in purs], "o-",  color="orange",    label="Purity [%]")
ax_pe.plot(ns.CUT_LABELS_MORE, [e * 100 for e in effs], "s--", color="steelblue", label="Efficiency [%]")
ax_pe.set_ylim(0, 105)
ax_pe.set_xticks(range(len(ns.CUT_LABELS_MORE)))
ax_pe.set_xticklabels(ns.CUT_LABELS_MORE, rotation=30, ha="right", fontsize=9)
ax_pe.set_ylabel("Percent [%]")
ax_pe.set_title("Purity & Efficiency")
ax_pe.legend(fontsize=9)
ax_pe.grid(alpha=0.3)

plt.tight_layout()
plt.show()
nh.save_plot("cutflow_pur_eff", fig=fig, folder_name=PLOT_DIR)

# ── Numeric table via matplotlib ──
fig_tab, ax_tab = plt.subplots(figsize=(9, 3))
nh.create_purity_efficiency_table(purs, effs, ns.CUT_LABELS_MORE, ax_tab)
fig_tab.tight_layout()
plt.show()
nh.save_plot("cutflow_table", fig=fig_tab, folder_name=PLOT_DIR)

# %%
# Efficiency & purity matrices (KE bins × cut stages) ────────────
ke_bins_c = np.array([0, 200, 400, 600, 800, 1000, 1500, 2000, np.inf])
ke_bin_labels = [
    "0–200", "200–400", "400–600", "600–800",
    "800–1k", "1k–1.5k", "1.5k–2k", ">2k",
]
n_bins = len(ke_bins_c) - 1
n_cuts = len(ns.CUT_NAMES_MORE)

# Align true KE to the common interaction index
true_ke_aligned = true_ke_all.reindex(common_idx)
sig_true_vals   = common_idx.isin(sig_inter_idx)

eff_matrix   = np.zeros((n_bins, n_cuts))
pur_matrix   = np.zeros((n_bins, n_cuts))
count_matrix = np.zeros((n_bins, n_cuts))
pur_count_matrix = np.zeros((n_bins, n_cuts))

for ci, cut_name in enumerate(ns.CUT_NAMES_MORE):
    cut_idx = cut_flow[cut_name]["inter_index"]
    reco_sel = common_idx.isin(cut_idx)

    _, purs_i, effs_i, total_sig_in_bin = nh.pur_eff_binned(
        values  = true_ke_aligned.fillna(-999).values,
        bins    = ke_bins_c,
        sel_mask = reco_sel,
        sig_mask = sig_true_vals,
    )

    selected_sig_in_bin   = np.zeros(n_bins)
    selected_total_in_bin = np.zeros(n_bins)
    for i, (lo, hi) in enumerate(zip(ke_bins_c[:-1], ke_bins_c[1:])):
        in_bin = (true_ke_aligned.fillna(-999).values >= lo) & \
                 (true_ke_aligned.fillna(-999).values < hi)
        selected_sig_in_bin[i]   = (in_bin & sig_true_vals & reco_sel).sum()
        selected_total_in_bin[i] = (in_bin & reco_sel).sum()          # ← new

    eff_matrix[:, ci] = np.nan_to_num(effs_i)
    pur_matrix[:, ci] = np.nan_to_num(purs_i)
    count_matrix[:, ci]     = selected_sig_in_bin    # for efficiency: sig passed
    pur_count_matrix[:, ci] = selected_total_in_bin  # for purity: total selected

for mat, count_mat, title, cmap, fname in [
    (eff_matrix, count_matrix,     "Efficiency", "Blues", "eff_matrix_true_ke_all_cuts"),
]:
    fig, ax = nh.plot_matrix_binned(
        mat, count_mat,                              # ← pass the right one
        bin_values        = np.arange(n_bins),
        bin_labels        = ke_bin_labels,
        cut_labels        = ns.CUT_LABELS_MORE,
        remove_dummy_col  = False,
        xlabel            = "True leading electron KE [MeV]",
        title             = title,
        cmap              = cmap,
    )
    fig.tight_layout()
    nh.save_plot(fname, fig=fig, folder_name=PLOT_DIR)

# %% [markdown]
# ### 5-2. Histograms

# %%
# Stacked histograms (reco KE and cos θ) ────────────────────────
 
# Use the final selection mask at particle level
final_pmask = cut_flow["single_electron"]["particle_mask"]
 
# Leading electron KE for each surviving interaction, categorised
reco_ke_all  = ns.leading_electron_ke(evtdf)   # interaction-level Series
reco_cos_all = ns.leading_electron_costheta(evtdf)
 
# Align truth categories
all_cats = sorted([c for c in nh.CAT_COLORS if c >= 0])
 
def _cat_ke_values(cat_code, sel_inter_idx):
    """reco leading-electron KE for interactions in sel_inter_idx with given category."""
    cat_inter = truth_cat[truth_cat == cat_code].index
    both = sel_inter_idx.intersection(cat_inter)
    return reco_ke_all.reindex(both).dropna().values
 
def _cat_cos_values(cat_code, sel_inter_idx):
    cat_inter = truth_cat[truth_cat == cat_code].index
    both = sel_inter_idx.intersection(cat_inter)
    return reco_cos_all.reindex(both).dropna().values
 
sel_idx = cut_flow["axial_spread"]["inter_index"]
 
ke_bins  = np.linspace(0, 2000, 41)    # MeV
cos_bins = np.linspace(-1, 1, 41)
 
# ── KE plot ──
fig_ke, ax_ke = plt.subplots(figsize=(8, 6))
nh.plot_stacked_hist(
    series_list = [_cat_ke_values(c, sel_idx) for c in all_cats],
    labels      = [nh.CAT_LABELS[c] for c in all_cats],
    colors      = [nh.CAT_COLORS[c] for c in all_cats],
    bins        = ke_bins,
    xlabel      = "Reco leading electron KE [MeV]",
    title       = fr"{TITLE}",
    pot_label   = f"MC {TARGET_POT:.1e} POT",
    ax          = ax_ke,
)
plt.show()
nh.save_plot("reco_electron_ke", fig=fig_ke, folder_name=PLOT_DIR)
 
# ── cos θ plot ──
fig_cos, ax_cos = plt.subplots(figsize=(8, 6))
nh.plot_stacked_hist(
    series_list = [_cat_cos_values(c, sel_idx) for c in all_cats],
    labels      = [nh.CAT_LABELS[c] for c in all_cats],
    colors      = [nh.CAT_COLORS[c] for c in all_cats],
    bins        = cos_bins,
    xlabel      = r"Reco leading electron $\cos\theta$",
    title       = fr"{TITLE}",
    pot_label   = f"MC {TARGET_POT:.1e} POT",
    ax          = ax_cos,
)
plt.show()
nh.save_plot("reco_electron_costheta", fig=fig_cos, folder_name=PLOT_DIR)

# %%
pause

# %%
import uproot
import awkward as ak
import pandas as pd
import numpy as np

def load_first_match(caf_path, particle=True):
    """
    Load match_ids and match_overlaps (first entry only) from a flat CAF.
    particle=True -> rec.dlp.particles.match_ids
    particle=False -> rec.dlp.match (slice-level)
    """
    with uproot.open(caf_path) as f:
        tree = f["recTree"]
        
        if particle:
            id_branch   = "rec.dlp.particles.match_ids"
            ovlp_branch = "rec.dlp.particles.match_overlaps"
        else:
            id_branch   = "rec.dlp.match"
            ovlp_branch = "rec.dlp.match_overlap"
        
        match_ids  = tree[id_branch].array()
        match_ovlp = tree[ovlp_branch].array()
        
        # take first element of each jagged array, NaN if empty
        first_id   = ak.to_numpy(ak.fill_none(ak.firsts(match_ids),  -1))
        first_ovlp = ak.to_numpy(ak.fill_none(ak.firsts(match_ovlp),  np.nan))
        
        return pd.DataFrame({
            "match_id":      first_id,
            "match_overlap": first_ovlp,
        })

# Usage:
caf = "/exp/sbnd/data/users/castalyf/nue_sel/production_files/gen1/input000-reweighted.flat.caf.root"
match_df = load_first_match(caf, particle=True)
print(match_df.head())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyanalib.pandas_helpers as ph
import pyanalib.split_df_helpers as splh

# ── 1. Load the df ──────────────────────────────────────────────────────
mc_file = "/home/castalyf/cafpyana_out/mc1e20.df"
keys2load = ['evt', 'hdr', 'mcnu']
mc_dfs = splh.load_dfs(mc_file, keys2load, n_max_concat=1)

evtdf  = mc_dfs['evt']    # particle-level: one row per SPINE particle
hdrdf  = mc_dfs['hdr']    # one row per event
mcnudf = mc_dfs['mcnu']   # one row per true neutrino interaction

# ── 2. POT scaling ──────────────────────────────────────────────────────
histpotdf = splh.load_dfs(mc_file, ['histpotdf'], n_max_concat=1)['histpotdf']
total_pot  = histpotdf['TotalPOT'].sum()
target_pot = 6.6e20  # adjust to your target
pot_scale  = target_pot / total_pot
print(f"Total POT: {total_pot:.3e}, Scale factor: {pot_scale:.3f}")

# ── 3. Basic SPINE particle cuts ─────────────────────────────────────────
parts = evtdf['particle']

# primary particles only
is_primary = parts['is_primary'] == 1

# valid reconstruction
is_valid = parts['is_valid'] == 1

# contained
is_contained = parts['is_contained'] == 1

# pid: SPINE pid codes are typically
#   0=photon, 1=electron, 2=muon, 3=pion, 4=proton
pid = parts['pid']
is_electron = pid == 1
is_muon     = pid == 2
is_proton   = pid == 4

# ── 4. nueCC inclusive selection ─────────────────────────────────────────
# Interaction level: require at least one primary electron
# Group by interaction index (first two index levels = entry, interaction)
inter_levels = list(range(evtdf.index.nlevels - 1))  # all but particle level

primary_electrons = evtdf[is_primary & is_valid & is_electron]

# interactions with at least one primary electron
has_electron = primary_electrons.groupby(level=inter_levels).size() > 0

# apply to evtdf
evtdf_nueCC = evtdf[evtdf.index.droplevel(-1).isin(has_electron[has_electron].index)]

print(f"Interactions passing nueCC selection: {has_electron.sum()}")
print(f"Particles in those interactions: {len(evtdf_nueCC)}")

# ── 5. Leading electron kinematics ───────────────────────────────────────
lead_electron = (
    evtdf[is_primary & is_valid & is_electron]
    ['particle']['ke']
    .groupby(level=inter_levels)
    .max()
)

plt.figure()
plt.hist(lead_electron.dropna(), bins=50, range=(0, 2000))
plt.xlabel("Leading electron KE (MeV)")
plt.ylabel("Interactions / bin")
plt.title("nueCC: Leading electron KE")
plt.tight_layout()
plt.savefig("lead_electron_ke.png")
plt.show()

# %%
import numpy as np
import pandas as pd
import pyanalib.pandas_helpers as ph
import pyanalib.split_df_helpers as splh

# ── 1. Load ONLY the evt (SPINE) table ───────────────────────────────────
mc_file = "/home/castalyf/cafpyana_out/mc1e20.df"
mc_dfs = splh.load_dfs(mc_file, ['evt'], n_max_concat=1)
evtdf = mc_dfs['evt']

print(f"Loaded evtdf shape: {evtdf.shape}")
print("Top-level column groups:", sorted(evtdf.columns.get_level_values(0).unique().tolist()))

# ── Helper: flatten any nested columns to clean leaf names ────────────────
def get_leaf_column_names(sub):
    """Return flat string branch names (handles pid_scores.I0, vertex.x, etc.)"""
    if isinstance(sub, pd.Series):
        return [sub.name]
    if isinstance(sub.columns, pd.MultiIndex):
        leaves = []
        for col_tuple in sub.columns.to_flat_index():
            flat = '.'.join(str(x) for x in col_tuple if x != '' and pd.notna(x))
            leaves.append(flat)
        return leaves
    else:
        return [str(c) for c in sub.columns.tolist()]

# ── 2. Load expected branches from branches.py (NOW INCLUDING TRUTH) ───────
branches_file = "/home/castalyf/cafpyana/makedf/branches.py"
with open(branches_file, 'r') as f:
    exec(f.read(), globals())  # loads ALL *branches lists including etruth*

expected_reco_inter = []
expected_reco_part = []
expected_truth_inter = []
expected_truth_part = []

for name, val in list(globals().items()):
    if name.endswith("branches") and isinstance(val, list):
        for b in val:
            if isinstance(b, str):
                if b.startswith("rec.dlp.") and ".particles." not in b and "true" not in b.lower():
                    stripped = b[len("rec.dlp."):].strip('.')
                    expected_reco_inter.append(stripped)
                elif "rec.dlp.particles." in b:
                    stripped = b.split("rec.dlp.particles.", 1)[1].strip('.')
                    expected_reco_part.append(stripped)
                elif b.startswith("rec.dlp_true."):
                    if ".particles." in b:
                        stripped = b.split("rec.dlp_true.particles.", 1)[1].strip('.')
                        expected_truth_part.append(stripped)
                    else:
                        stripped = b[len("rec.dlp_true."):].strip('.')
                        expected_truth_inter.append(stripped)

for d in (expected_reco_inter, expected_reco_part, expected_truth_inter, expected_truth_part):
    d[:] = sorted(set(d))

print(f"Expected reco interaction-level: {len(expected_reco_inter)}")
print(f"Expected reco particle-level:    {len(expected_reco_part)}")
print(f"Expected truth interaction-level:{len(expected_truth_inter)}")
print(f"Expected truth particle-level:   {len(expected_truth_part)}")

# ── 3. Detect groups & collect AVAILABLE branches (reco + truth) ──────────
particle_group = 'particle' if 'particle' in evtdf.columns.get_level_values(0) else None

# Reco interaction (everything NOT particle and NOT truth)
avail_reco_inter = set()
for g in evtdf.columns.get_level_values(0).unique():
    if g == particle_group or 'true' in str(g).lower():
        continue
    sub = evtdf[g]
    avail_reco_inter.update(get_leaf_column_names(sub))

# Reco particle
avail_reco_part = set()
if particle_group:
    sub_p = evtdf[particle_group]
    avail_reco_part = set(get_leaf_column_names(sub_p))

# Truth groups (dlp_true.*)
truth_groups = [g for g in evtdf.columns.get_level_values(0).unique() if 'true' in str(g).lower()]
print(f"→ Detected truth groups: {truth_groups or 'None (truth table not present in this CAF)'}")

avail_truth_inter = set()
avail_truth_part = set()
for g in truth_groups:
    sub = evtdf[g]
    leaves = get_leaf_column_names(sub)
    if 'particles' in str(g).lower():
        avail_truth_part.update(leaves)
    else:
        avail_truth_inter.update(leaves)

# ── 4. Build clean combined DataFrame (now with truth sections) ───────────
data = []

for level, exp_list, avail_set in [
    ('reco_interaction', expected_reco_inter, avail_reco_inter),
    ('reco_particle',    expected_reco_part,   avail_reco_part),
    ('truth_interaction', expected_truth_inter, avail_truth_inter),
    ('truth_particle',   expected_truth_part,  avail_truth_part),
]:
    combined = sorted(set(exp_list) | avail_set)
    for b in combined:
        data.append({
            'Level': level,
            'Branch': b,
            'Expected (branches.py)': b in exp_list,
            'Available in df': b in avail_set
        })

clean_df = pd.DataFrame(data)
clean_df = clean_df.sort_values(by=['Level', 'Branch']).reset_index(drop=True)

print("\n=== CLEAN DF: All SPINE (dlp) branches (reco + truth) ===")
print(clean_df.to_string(index=False))
